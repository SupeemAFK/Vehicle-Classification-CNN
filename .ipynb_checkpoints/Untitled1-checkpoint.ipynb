# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 531 files belonging to 4 classes.

# %%
train_size = int(len(data) * .5) #=> math floor 7
val_size = int(len(data) * .1) #=> math floor 2
test_size = int(len(data) * .1) #=> math floor 1
train_size, val_size, test_size
# Out:
# (8, 1, 1)

# %%
train_data = data.take(train_size)
val_data = data.skip(train_size).take(val_size)
test_data = data.skip(train_size + val_size).take(test_size)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
preprocess_input = tf.keras.applications.resnet50.preprocess_input

# %%
train_data = train_data.map(lambda x, y: (data_augmentation(x), y))
train_data = train_data.map(lambda x, y: (preprocess_input(x), y))
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
pretrained_model = tf.keras.applications.ResNet50(include_top=False, input_shape=(256, 256, 3), pooling='avg', classes=4, weights='imagenet')
for layer in pretrained_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

model = Sequential()
model.add(pretrained_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(4, activation='softmax'))

# %%
model.compile('adam',
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 24,113,284
# Trainable params: 525,572
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(train_data,
                    epochs=50,
                    validation_data=val_data)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 23s 2s/step - loss: 1.1546 - accuracy: 0.6680 - val_loss: 0.5861 - val_accuracy: 0.7188
# Epoch 2/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.1774 - accuracy: 0.9375 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 3/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0894 - accuracy: 0.9727 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 4/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 5/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0151 - accuracy: 0.9961 - val_loss: 0.0425 - val_accuracy: 0.9688
# Epoch 6/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 7/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 8/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9688
# Epoch 9/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 10/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 11/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 12/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0360 - accuracy: 0.9805 - val_loss: 0.0311 - val_accuracy: 0.9688
# Epoch 13/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0259 - accuracy: 0.9961 - val_loss: 0.1651 - val_accuracy: 0.9375
# Epoch 14/50
# 8/8 [==============================] - 18s 2s/step - loss: 0.0195 - accuracy: 0.9961 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 15/50
# 8/8 [==============================] - 18s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 16/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 17/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 18/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 19/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 9.4421e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0049 - accuracy: 0.9961 - val_loss: 6.3010e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 22/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 23/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 24/50
# 8/8 [==============================] - 17s 2s/step - loss: 7.8221e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 25/50
# 8/8 [==============================] - 17s 2s/step - loss: 9.6343e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 26/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 27/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 28/50
# 8/8 [==============================] - 17s 2s/step - loss: 9.5708e-04 - accuracy: 1.0000 - val_loss: 8.7061e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 8/8 [==============================] - 17s 2s/step - loss: 8.4164e-04 - accuracy: 1.0000 - val_loss: 6.9267e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 8/8 [==============================] - 20s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 31/50
# 8/8 [==============================] - 18s 2s/step - loss: 4.5770e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9688
# Epoch 32/50
# 8/8 [==============================] - 18s 2s/step - loss: 2.5342e-04 - accuracy: 1.0000 - val_loss: 9.7291e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 34/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 6.4619e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 8/8 [==============================] - 17s 2s/step - loss: 9.4209e-04 - accuracy: 1.0000 - val_loss: 1.2028e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0053 - accuracy: 0.9961 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 37/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0053 - accuracy: 0.9961 - val_loss: 0.0417 - val_accuracy: 0.9688
# Epoch 38/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9375
# Epoch 39/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 6.0050e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 8/8 [==============================] - 17s 2s/step - loss: 5.1970e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 41/50
# 8/8 [==============================] - 17s 2s/step - loss: 6.1405e-04 - accuracy: 1.0000 - val_loss: 4.6907e-05 - val_accuracy: 1.0000
# Epoch 42/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0045 - accuracy: 0.9961 - val_loss: 0.0341 - val_accuracy: 0.9688
# Epoch 43/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0067 - accuracy: 0.9961 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 44/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 45/50
# 8/8 [==============================] - 17s 2s/step - loss: 6.6538e-04 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9688
# Epoch 46/50
# 8/8 [==============================] - 17s 2s/step - loss: 5.6969e-04 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 47/50
# 8/8 [==============================] - 17s 2s/step - loss: 3.5107e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 48/50
# 8/8 [==============================] - 17s 2s/step - loss: 3.9820e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 49/50
# 8/8 [==============================] - 17s 2s/step - loss: 6.7155e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 50/50
# 8/8 [==============================] - 17s 2s/step - loss: 4.0792e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
print("Evaluate on test data")
x_test, y_test = test_data.as_numpy_iterator().next()
results = model.evaluate(x_test, y_test, batch_size=128)
print("test loss: {loss}, test acc: {acc}".format(loss=results[0], acc=results[1]))
# Out:
# Evaluate on test data
# 1/1 [==============================] - 1s 1s/step - loss: 9.8996e-05 - accuracy: 1.0000
# test loss: {loss}, test acc: {acc}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       2 x_test, y_test = test_data.as_numpy_iterator().next()
#       3 results = model.evaluate(x_test, y_test, batch_size=128)
# ----> 4 print("test loss: {loss}, test acc: {acc}").format(loss=results[0], acc=results[1])
#
# AttributeError: 'NoneType' object has no attribute 'format'

# %%
img = cv2.imread('151130evymvumbmgo589ku.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(preprocess_input(resize), 0))
yhat[0]
# Out:
# 1/1 [==============================] - 0s 95ms/step
# array([1.5846751e-11, 1.3104979e-06, 9.9999869e-01, 3.5213088e-09],
#       dtype=float32)

# %%
index = yhat[0].argmax()
if (index == 0):
    print("Boat")
elif (index == 1):
    print("Car")
elif (index == 2):
    print("Motorcycles")
elif (index == 3):
    print("Plane")
# Out:
# Motorcycles
